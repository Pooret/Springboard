# %%
# https://towardsdatascience.com/sentiment-analysis-for-stock-price-prediction-in-python-bed40c65d178

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import twint
from bs4 import BeautifulSoup
import re
import yfinance as yf
from nltk.tokenize import WordPunctTokenizer
import flair

# Fixes runtime errors and compatibility issues while running Twint in notebook
import nest_asyncio
nest_asyncio.apply()

# %%
# Configure twint search settings (https://github.com/twintproject/twint/wiki/Configuration)
c = twint.Config()
c.Username = 'elonmusk'
c.User_full = True
c.Count = True
c.Stats = True
c.Pandas = True
c.Store_pandas = True
c.Hide_output = True
c.Pandas_clean = True
#c.Limit = 10
c.Since = '2019-01-01'
#c.Search = 'TSLA'

# %%
# Run twint search with configurations
twint.run.Search(c)
# Out:
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [+] Finished: Successfully collected 7159 Tweets from @elonmusk.

# %%
# Set columns for dataframe

def available_columns():
    return twint.output.panda.Tweets_df.columns
def twint_to_pandas(columns):
    return twint.output.panda.Tweets_df[columns]

# %%
available_columns()
# Out:
# Index(['id', 'conversation_id', 'created_at', 'date', 'timezone', 'place',
#        'tweet', 'language', 'hashtags', 'cashtags', 'user_id', 'user_id_str',
#        'username', 'name', 'day', 'hour', 'link', 'urls', 'photos', 'video',
#        'thumbnail', 'retweet', 'nlikes', 'nreplies', 'nretweets', 'quote_url',
#        'search', 'near', 'geo', 'source', 'user_rt_id', 'user_rt',
#        'retweet_id', 'reply_to', 'retweet_date', 'translate', 'trans_src',
#        'trans_dest'],
#       dtype='object')

# %%
# Turn into pandas DataFrame
df_pd = twint_to_pandas(["date", "day", "hour", "username", "tweet", "hashtags", "nlikes", "nreplies", "nretweets"])

# %%
df_pd.head(3)
# Out:
#                   date  day hour  username  \
# 0  2021-04-26 15:11:05    1   15  elonmusk
# 1  2021-04-26 14:10:31    1   14  elonmusk
# 2  2021-04-26 02:11:54    1   02  elonmusk
#
#                                                tweet hashtags  nlikes  \
# 0  @PPathole An advantage I did have is that my f...       []    2160
# 1  @PPathole True. The opposite in fact – I provi...       []    2680
# 2  @BLKMDL3 @JohnnaCrider1 We just got approval t...       []    3611
#
#    nreplies  nretweets
# 0       213        209
# 1       243        269
# 2       337        213

# %%
df_pd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7156 entries, 0 to 7155
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       7156 non-null   object
#  1   day        7156 non-null   int64
#  2   hour       7156 non-null   object
#  3   username   7156 non-null   object
#  4   tweet      7156 non-null   object
#  5   hashtags   7156 non-null   object
#  6   nlikes     7156 non-null   int64
#  7   nreplies   7156 non-null   int64
#  8   nretweets  7156 non-null   int64
# dtypes: int64(4), object(5)
# memory usage: 503.3+ KB

# %%
# Convert date column to datetime

df_pd['date'] = pd.to_datetime(df_pd['date'])
df_pd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7156 entries, 0 to 7155
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       7156 non-null   datetime64[ns]
#  1   day        7156 non-null   int64
#  2   hour       7156 non-null   object
#  3   username   7156 non-null   object
#  4   tweet      7156 non-null   object
#  5   hashtags   7156 non-null   object
#  6   nlikes     7156 non-null   int64
#  7   nreplies   7156 non-null   int64
#  8   nretweets  7156 non-null   int64
# dtypes: datetime64[ns](1), int64(4), object(4)
# memory usage: 503.3+ KB
# <ipython-input-9-98e876b7fdae>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pd['date'] = pd.to_datetime(df_pd['date'])

# %%
# tweet_df = df_pd.set_index('date')
tweet_df = df_pd

# %%
tweet_df.head(3)
# Out:
#                  date  day hour  username  \
# 0 2021-04-26 15:11:05    1   15  elonmusk
# 1 2021-04-26 14:10:31    1   14  elonmusk
# 2 2021-04-26 02:11:54    1   02  elonmusk
#
#                                                tweet hashtags  nlikes  \
# 0  @PPathole An advantage I did have is that my f...       []    2160
# 1  @PPathole True. The opposite in fact – I provi...       []    2680
# 2  @BLKMDL3 @JohnnaCrider1 We just got approval t...       []    3611
#
#    nreplies  nretweets
# 0       213        209
# 1       243        269
# 2       337        213

# %%
# Look for duplicates

duplicated = tweet_df[tweet_df.duplicated(['tweet'])]

# %%
duplicated.count()
# Out:
# date         50
# day          50
# hour         50
# username     50
# tweet        50
# hashtags     50
# nlikes       50
# nreplies     50
# nretweets    50
# dtype: int64

# %%
duplicated
# Out:
#                     date  day hour  username  \
# 847  2021-01-07 05:23:50    4   05  elonmusk
# 980  2020-12-16 23:08:02    3   23  elonmusk
# 1157 2020-11-17 13:48:50    2   13  elonmusk
# 1807 2020-09-04 14:21:48    5   14  elonmusk
# 2147 2020-07-30 03:54:43    4   03  elonmusk
# 2280 2020-07-21 01:19:10    2   01  elonmusk
# 2431 2020-07-05 16:36:16    7   16  elonmusk
# 2447 2020-07-04 22:40:55    6   22  elonmusk
# 2622 2020-06-21 23:18:52    7   23  elonmusk
# 2637 2020-06-21 04:07:42    7   04  elonmusk
# 2701 2020-06-16 03:09:09    2   03  elonmusk
# 2807 2020-06-01 22:54:03    1   22  elonmusk
# 2858 2020-05-22 20:14:39    5   20  elonmusk
# 2878 2020-05-19 20:23:35    2   20  elonmusk
# 2904 2020-05-15 14:39:28    5   14  elonmusk
# 3144 2020-05-03 03:43:14    7   03  elonmusk
# 3356 2020-04-18 18:06:57    6   18  elonmusk
# 3375 2020-04-17 14:17:23    5   14  elonmusk
# 3466 2020-04-10 03:42:17    5   03  elonmusk
# 3645 2020-03-22 20:34:05    7   20  elonmusk
# 3752 2020-03-11 11:18:25    3   11  elonmusk
# 3832 2020-02-26 01:33:33    3   01  elonmusk
# 3952 2020-02-08 18:10:37    6   18  elonmusk
# 3969 2020-02-06 14:13:04    4   14  elonmusk
# 3981 2020-02-06 05:37:14    4   05  elonmusk
# 3995 2020-02-05 17:07:46    3   17  elonmusk
# 4100 2020-01-23 15:29:34    4   15  elonmusk
# 4132 2020-01-17 17:13:48    5   17  elonmusk
# 4246 2019-12-30 03:03:12    1   03  elonmusk
# 4385 2019-12-21 14:25:25    6   14  elonmusk
# 4613 2019-11-07 15:47:44    4   15  elonmusk
# 4813 2019-10-09 03:57:55    3   03  elonmusk
# 4842 2019-10-06 12:08:11    7   12  elonmusk
# 5009 2019-09-17 12:40:54    2   12  elonmusk
# 5058 2019-09-13 19:21:36    5   19  elonmusk
# 5100 2019-09-10 04:09:14    2   04  elonmusk
# 5170 2019-09-04 05:30:00    3   05  elonmusk
# 5184 2019-08-29 23:39:21    4   23  elonmusk
# 5573 2019-07-13 03:49:00    6   03  elonmusk
# 5745 2019-06-24 06:47:51    1   06  elonmusk
# 5758 2019-06-23 17:21:35    7   17  elonmusk
# 5855 2019-06-09 14:10:01    7   14  elonmusk
# 6059 2019-05-11 20:43:18    6   20  elonmusk
# 6678 2019-03-10 23:17:30    7   23  elonmusk
# 6729 2019-03-03 17:48:15    7   17  elonmusk
# 6769 2019-03-01 02:12:10    5   02  elonmusk
# 6966 2019-01-31 21:16:28    4   21  elonmusk
# 7066 2019-01-12 16:27:20    6   16  elonmusk
# 7075 2019-01-10 22:48:48    4   22  elonmusk
# 7076 2019-01-10 22:47:22    4   22  elonmusk
#
#                                                  tweet hashtags  nlikes  \
# 847   The most entertaining outcome is the most likely       []  156003
# 980                                  @TheBabylonBee 🤣🤣       []   25366
# 1157                             @westcoastbill Indeed       []    1039
# 1807                                @Tesmanian_com Yes       []    7166
# 2147                             @tobyliiiiiiiiii Sure       []    5638
# 2280                                       @flcnhvy 🤣🤣       []    2983
# 2431                                 @WholeMarsBlog 🤣🤣       []   17319
# 2447                                    @nichegamer 🤣🤣       []    3204
# 2622                              @TeslaOwnersEBay Yes       []    1613
# 2637                     We must pass The Great Filter       []  173133
# 2701                               @cleantechnica Cool       []    5675
# 2807                           Off Twitter for a while       []  522564
# 2858                                    @nichegamer 🤣🤣       []    5489
# 2878                                     @flcnhvy True       []    5200
# 2904                                     @flcnhvy True       []     977
# 3144                        @cleantechnica Pretty much       []    3797
# 3356                                    @nichegamer 🤣🤣       []    3615
# 3375                                     @flcnhvy True       []    2812
# 3466                                    @nichegamer 🤣🤣       []   15044
# 3645                              @engineers_feed Nice       []    5443
# 3752                                  @JaneidyEve Sure       []    3682
# 3832                                      @flcnhvy Yes       []    1412
# 3952                                     @flcnhvy True       []    3008
# 3969                                     @flcnhvy True       []    8295
# 3981                              @engineers_feed Nice       []    3999
# 3995                               @RationalEtienne 🤣🤣       []    3636
# 4100                                @Erdayastronaut Ok       []   12635
# 4132                                   @JaneidyEve Yes       []    1157
# 4246                               @Erdayastronaut Yes       []    1480
# 4385                                @teslaownersSV Yes       []     850
# 4613                               @cleantechnica True       []    1218
# 4813                                @teslaownersSV Yes       []    6738
# 4842                               @teslaownersSV Sure       []    2763
# 5009                               @Erdayastronaut Yes       []    1708
# 5058                                @Kristennetten Yes       []    1251
# 5100                              @tesla_truth Exactly       []    6650
# 5170                                  @nichegamer Nice       []   22503
# 5184                              @tesla_truth Exactly       []    3164
# 5573                                                 🔥       []   21411
# 5745                                     @EvaFoxU Haha       []     315
# 5758                                       @flcnhvy 🤣🤣       []   10330
# 5855                             @TesLatino @Tesla Yes       []     878
# 6059                                      @gorosart Ok       []   14650
# 6678                               @cleantechnica True       []    5662
# 6729                                @teslaownersSV Yes       []     912
# 6769                               @Erdayastronaut Yes       []    5058
# 6966                             @TriTexan @SpaceX Yes       []    1117
# 7066                                 @teslaownersSV Ok       []     728
# 7075                                    @somepitch Yes       []     619
# 7076                               @Erdayastronaut Yes       []    1376
#
#       nreplies  nretweets
# 847       3360      10409
# 980        589        381
# 1157        54         30
# 1807       323        210
# 2147       264         82
# 2280        58         29
# 2431       204        204
# 2447       175         55
# 2622        81         41
# 2637      6330      14868
# 2701       146        151
# 2807     21846      27967
# 2858        76         67
# 2878       160        119
# 2904        35         27
# 3144       177        101
# 3356        51         84
# 3375        85         74
# 3466       114        195
# 3645       102        159
# 3752        92        102
# 3832        48         58
# 3952        88         67
# 3969       129         91
# 3981       114        111
# 3995        40         73
# 4100       220        202
# 4132        60         47
# 4246        35         49
# 4385       144         50
# 4613        33         55
# 4813        81         89
# 4842        79         44
# 5009        36         48
# 5058        57         25
# 5100       111        173
# 5170       495        968
# 5184       131         88
# 5573       545        731
# 5745         8          9
# 5758        71        160
# 5855        52         28
# 6059        90        318
# 6678        77        113
# 6729        47         34
# 6769       100         74
# 6966        25         17
# 7066        65         20
# 7075        10         15
# 7076        53         30

# %%
# Will keep duplicates for now

# Remove unneccesary columns

del tweet_df['username']

# %%
# Check length of each tweet

tweet_df['pre_clean_len'] = [len(i) for i in tweet_df['tweet']]
# Out:
# <ipython-input-16-6e4c2772ef8b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tweet_df['pre_clean_len'] = [len(i) for i in tweet_df['tweet']]

# %%
ordered = tweet_df.sort_values(by='pre_clean_len', ascending=False)

# %%
ordered.head()
# Out:
#                     date  day hour  \
# 4415 2019-12-13 21:31:32    5   21
# 3424 2020-04-15 22:10:25    3   22
# 3423 2020-04-15 22:18:55    3   22
# 3430 2020-04-15 21:50:01    3   21
# 3418 2020-04-15 22:38:55    3   22
#
#                                                   tweet hashtags  nlikes  \
# 4415  @bluemoondance74 @ThugsAndMiracle @tfspeakcies...       []    6556
# 3424  @fat__tire @Kristennetten @Robotbeat @ghotiing...       []     662
# 3423  @sivanithu @tobyliiiiiiiiii @cabral_psyd @Erda...       []    1513
# 3430  @Robotbeat @ghotiing @CruizVinicius @josh11987...       []     893
# 3418  @Erdayastronaut @sivanithu @tobyliiiiiiiiii @c...       []    2458
#
#       nreplies  nretweets  pre_clean_len
# 4415       191        662            424
# 3424       172         71            394
# 3423        28         66            394
# 3430       232         93            381
# 3418       130        136            371

# %%
# Need to remove retweets with characters with @.

tweet_df[tweet_df['pre_clean_len'] > 140].head()
# Out:
#                   date  day hour  \
# 0  2021-04-26 15:11:05    1   15
# 23 2021-04-22 16:20:50    4   16
# 26 2021-04-22 02:02:03    4   02
# 30 2021-04-22 01:38:03    4   01
# 31 2021-04-22 01:14:54    4   01
#
#                                                 tweet hashtags  nlikes  \
# 0   @PPathole An advantage I did have is that my f...       []    2160
# 23  @AstroJordy I’m staying at a friend’s place in...       []    3564
# 26  @JohnnaCrider1 @WholeMarsBlog If Tesla owners ...       []    3668
# 30  @annerajb Newest units can probably do as much...       []    1544
# 31  Powerwall 2 peak &amp; steady power capability...       []   26789
#
#     nreplies  nretweets  pre_clean_len
# 0        213        209            175
# 23       315        277            272
# 26       229        407            309
# 30        55         96            261
# 31      1265       1224            285

# %%
# Cleaning data

# It seems that some of the HMTL encoding has not been properly converted (https://towardsdatascience.com/another-twitter-sentiment-analysis-bb5b01ebad90)
def clean_html(tweet):
    """NEED TO FILL"""
    return str(tweet).replace('&amp;', '&').replace('&lt;', '<').replace('&gt;', '>').replace('&quot;', '"').replace('&#39;', "'")
# Remove mentions
def clean_mention(tweet):
    """NEED TO FILL"""
    return re.sub(r'@[A-Za-z0-9_]+','', tweet)
# Remove URLS
def clean_url(tweet):
    """NEED TO FILL"""
    return re.sub('https?://[A-Za-z0-9./]+','', tweet)

# %%
#tweet_df.loc['2021-04-22 01:14:54']['tweet']
#_ = tweet_df.loc['2021-04-22 01:14:54']['tweet'].apply(clean_html)
#_

# %%
#tweet_df.loc['2021-04-22 01:38:03']['tweet']

# %%
#_ = tweet_df.loc['2021-04-22 01:38:03']['tweet'].apply(clean_mention)

# %%
cleaned_tweet = tweet_df['tweet'].apply(clean_html).apply(clean_mention).apply(clean_url).str.lower()
cleaned_df = tweet_df
cleaned_df['tweet'] = cleaned_tweet
# Out:
# <ipython-input-24-0d555e05c32a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df['tweet'] = cleaned_tweet

# %%
cleaned_tweet
# Out:
# 0        an advantage i did have is that my father is ...
# 1        true. the opposite in fact – i provide financ...
# 2         we just got approval to open a new superchar...
# 3
# 4                                             so awesome!
#                               ...
# 7151      yes, support of the chinese government is ve...
# 7152                              govt has been unwelcome
# 7153                                     congratulations!
# 7154                            great work by tesla team!
# 7155                            congratulations  team!!
# Name: tweet, Length: 7156, dtype: object

# %%
del cleaned_df['pre_clean_len']
cleaned_df['clean_len'] = [len(i) for i in cleaned_df['tweet']]
# Out:
# <ipython-input-26-e3f670dbf4f0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df['clean_len'] = [len(i) for i in cleaned_df['tweet']]

# %%
_ = cleaned_df.sort_values(by='clean_len')

# %%
_
# Out:
#                     date  day hour  \
# 3750 2020-03-11 11:32:06    3   11
# 3811 2020-03-02 03:59:46    1   03
# 641  2021-01-31 16:07:41    7   16
# 4413 2019-12-13 21:55:49    5   21
# 839  2021-01-07 13:49:47    4   13
# ...                  ...  ...  ...
# 6631 2019-03-16 16:38:07    6   16
# 4304 2019-12-28 18:22:36    6   18
# 2564 2020-06-30 18:01:31    2   18
# 4011 2020-02-03 12:14:41    1   12
# 2493 2020-07-03 16:23:20    5   16
#
#                                                   tweet hashtags  nlikes  \
# 3750                                                          []  226467
# 3811                                                          []   96835
# 641                                                           []   36330
# 4413                                                          []   91012
# 839                                                           []  317781
# ...                                                 ...      ...     ...
# 6631     model 3 partial permanent magnet induction ...       []    1354
# 4304       we started zip2 with ~$2k from me plus my...       []    3993
# 2564      extremely big difference between died beca...       []    1276
# 4011      first, we need to make it super safe & eas...       []    2423
# 2493      the news is sometimes created, but always ...       []    3120
#
#       nreplies  nretweets  clean_len
# 3750      4860      22333          1
# 3811       863      12515          1
# 641       2998       3194          1
# 4413       922       4588          1
# 839       7068      24434          1
# ...        ...        ...        ...
# 6631        65         79        283
# 4304       126        327        283
# 2564       259        121        284
# 4011        74        138        284
# 2493       641        539        284
#
# [7156 rows x 9 columns]

# %%
# removing hashtag column for now

del cleaned_df['hashtags']

# %%
small = cleaned_df[cleaned_df['clean_len'] == 1]

# %%
small
# Out:
#                     date  day hour tweet  nlikes  nreplies  nretweets  \
# 9    2021-04-24 05:03:34    6   05        227115      6506      18313
# 59   2021-04-16 13:01:25    5   13     👀  257572     14161      26867
# 139  2021-04-09 03:32:42    5   03        350815      6523      34967
# 301  2021-03-18 22:40:07    4   22        343139      8786      23645
# 392  2021-03-05 17:37:43    5   17     🙄  271834     16082      17736
# ...                  ...  ...  ...   ...     ...       ...        ...
# 6935 2019-02-03 23:03:22    7   23         78670      2157       9432
# 6936 2019-02-03 22:56:56    7   22        144404      2478      19780
# 7070 2019-01-10 23:42:49    4   23          5582       242        400
# 7108 2019-01-06 14:45:28    7   14         47703       872       5088
# 7136 2019-01-04 14:47:50    5   14     …  133217      6759      18119
#
#       clean_len
# 9             1
# 59            1
# 139           1
# 301           1
# 392           1
# ...         ...
# 6935          1
# 6936          1
# 7070          1
# 7108          1
# 7136          1
#
# [77 rows x 8 columns]

# %%
cleaned_df = cleaned_df[cleaned_df['clean_len'] > 1]

# %%
cleaned_df
# Out:
#                     date  day hour  \
# 0    2021-04-26 15:11:05    1   15
# 1    2021-04-26 14:10:31    1   14
# 2    2021-04-26 02:11:54    1   02
# 3    2021-04-26 02:08:53    1   02
# 4    2021-04-25 15:41:31    7   15
# ...                  ...  ...  ...
# 7151 2019-01-03 12:51:34    4   12
# 7152 2019-01-03 09:14:25    4   09
# 7153 2019-01-02 23:47:23    3   23
# 7154 2019-01-02 20:25:02    3   20
# 7155 2019-01-01 02:17:51    2   02
#
#                                                   tweet  nlikes  nreplies  \
# 0      an advantage i did have is that my father is ...    2160       213
# 1      true. the opposite in fact – i provide financ...    2680       243
# 2       we just got approval to open a new superchar...    3611       337
# 3                                                         10005       408
# 4                                           so awesome!   11697       484
# ...                                                 ...     ...       ...
# 7151    yes, support of the chinese government is ve...     743        31
# 7152                            govt has been unwelcome    1001        69
# 7153                                   congratulations!   14212       186
# 7154                          great work by tesla team!   32546       687
# 7155                          congratulations  team!!     73574      1019
#
#       nretweets  clean_len
# 0           209        162
# 1           269         72
# 2           213         68
# 3           279          2
# 4           386         12
# ...         ...        ...
# 7151         50         65
# 7152         54         24
# 7153        441         17
# 7154       2346         25
# 7155       2946         25
#
# [7079 rows x 8 columns]

# %%
_ = cleaned_df.sort_values(by='clean_len')

# %%
_
# Out:
#                     date  day hour  \
# 605  2021-02-05 06:49:29    5   06
# 5152 2019-09-06 18:01:54    5   18
# 1567 2020-10-05 18:42:24    1   18
# 1566 2020-10-05 18:58:07    1   18
# 1436 2020-10-14 19:17:27    3   19
# ...                  ...  ...  ...
# 5907 2019-05-27 02:32:24    1   02
# 3025 2020-05-09 12:49:40    6   12
# 2564 2020-06-30 18:01:31    2   18
# 4011 2020-02-03 12:14:41    1   12
# 2493 2020-07-03 16:23:20    5   16
#
#                                                   tweet  nlikes  nreplies  \
# 605                                                   🖤   40428       796
# 5152                                                  😲    1501       118
# 1567                                                        436        32
# 1566                                                  💯     457        16
# 1436                                                  😢   29360       291
# ...                                                 ...     ...       ...
# 5907     there are already 4900 satellites in orbit,...    1493       202
# 3025     san joaquin county, right next door to alam...    2087       126
# 2564      extremely big difference between died beca...    1276       259
# 4011      first, we need to make it super safe & eas...    2423        74
# 2493      the news is sometimes created, but always ...    3120       641
#
#       nretweets  clean_len
# 605         621          2
# 5152         62          2
# 1567         16          2
# 1566         13          2
# 1436        623          2
# ...         ...        ...
# 5907        195        283
# 3025        221        283
# 2564        121        284
# 4011        138        284
# 2493        539        284
#
# [7079 rows x 8 columns]

# %%
# Tokenization 
# https://towardsdatascience.com/another-twitter-sentiment-analysis-bb5b01ebad90
# https://towardsdatascience.com/sentiment-analysis-for-stock-price-prediction-in-python-bed40c65d178
